# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
import tarfile

def recursive_files(dir_name='.', ignore=None):
    for dir_name,subdirs,files in os.walk(dir_name):
        if ignore and os.path.basename(dir_name) in ignore: 
            continue

        for file_name in files:
            if ignore and file_name in ignore:
                continue

            yield os.path.join(dir_name, file_name)

def make_tar_file(dir_name='.', tar_file_name='tarfile.tar', ignore=None):
    tar = tarfile.open(tar_file_name, 'w')

    for file_name in recursive_files(dir_name, ignore):
        tar.add(file_name)

    tar.close()


dir_name = '.'
tar_file_name = 'archive.tar'
ignore = {'.ipynb_checkpoints', '__pycache__', tar_file_name}
make_tar_file(dir_name, tar_file_name, ignore)

# %%
def plot_average_reward_2 (filename_1, filename_2,filename_3,filename_4,filename_5 , filename_6,  color1, color2, color3, color4,color5,color6   ):
    plt.figure(figsize=(20,10))
    step = []
    reward = []
    with open(filename_1,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
    label = "Maxmin DQN net=2 set=1"
 
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)] #每十个计算均值
    plt.plot(step, avg, color1, label =label  )
  
    
    step = []
    reward = []
    with open(filename_2,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
        
    label = "Maxmin DQN net=4 set=1"
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)]
 
    plt.plot(step, avg, color2, label =  label  )
    
    step = []
    reward = []
    with open(filename_3,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
       
    label = "Maxmin DQN net=6 set=1"
    
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)]
     
    plt.plot(step, avg, color3, label =  label  )
    
    step = []
    reward = []
    with open(filename_4,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
         
    label = "Maxmin DQN net=8 set=1"
    
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)]
 
    plt.plot(step, avg, color4, label =  label  )
    
    step = []
    reward = []
    with open(filename_5,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
         
    label = "DQN"
    
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)]
 
    plt.plot(step, avg, color5, label =  label  )
    
    step = []
    reward = []
    with open(filename_6,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
         
    label = "DDQN"
    
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)]
 
    plt.plot(step, avg, color6, label =  label  )
    
    
    plt.ylabel("Average Rewards", fontsize=20)
    plt.xlabel("Training Steps(10^5)", fontsize=20)
    plt.ylim(0,3000)
    # {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'}
    plt.legend(fontsize="large")

 
    plt.savefig(  'result.png')

# %%
plot_average_reward_2( 
                      "AsMaxminQnet2set12022-01-19 10_45skip4_use_Atari.txt",
                      "AsMaxminQnet4set12022-01-19 15_02skip4_use_Atari.txt", 
                      "AsMaxminQnet6set12022-01-19 17_22skip4_use_Atar.txt" , 
                      "AsMaxminQnet8set12022-01-19 16_46skip4_use_Atari.txt"  ,
                      "AsDQNnet2set12022-01-19 17_23skip4_use_Atari.txt",
                      "AsDDQNnet2set12022-01-20 02_31skip4_use_Atari.txt",
                      'r'  ,'b','c' ,'y','m' ,'black' )

# %%
def plot_average_reward_2 (filename_1, filename_2, color1, color2  ):
    plt.figure(figsize=(20,10))
    step = []
    reward = []
    with open(filename_1,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
    label = "Maxmin DQN net=2 set=1"
 
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)] #每十个计算均值
    plt.plot(step, avg, color1, label =label  )
  
    
    step = []
    reward = []
    with open(filename_2,"r") as f:
        line = f.readlines()
    for i in line:
        l = i.split()
        if l==[]:
            break
        if(int(l[1]) % 100000==0   ):
            step.append(int(l[1])  // 100000  )
        reward.append(float(l[2]))
        
    label = "Maxmin DQN_V2 net=2 set=1"
    avg = [sum(reward[i*10:(i+1)*10])/10 for i in range(len(reward)//10)]
 
    plt.plot(step, avg, color2, label =  label  )

    plt.ylabel("Average Rewards", fontsize=20)
    plt.xlabel("Training Steps(10^5)", fontsize=20)
    plt.ylim(0,3000)
    # {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'}
    plt.legend(fontsize="large")

 
    plt.savefig(  'result.png')

# %%
plot_average_reward_2( 
                      "BrMaxminQnet2set12022-01-12 02_16skip4_use_Myenv.txt",
                      "BrM2net2set12022-01-20 07_12skip4_use_Atar.txt", 
                      'r'  ,'b' )
